# %%
temperatures = [5, 12.5, 17.3, 9.8, 20.1, 14.2, 15.0, 18.6, 8.7, 10.0]

cold = []
mild = []
comfortable = []

for temp in temperatures:
    if temp < 10:
        cold.append(temp)
    elif 10 <= temp < 15:
        mild.append(temp)
    elif 15 <= temp < 20:
        comfortable.append(temp)

print("Cold temperatures:", cold)
print("Mild temperatures:", mild)
print("Comfortable temperatures:", comfortable)
# Out:
# Cold temperatures: [5, 9.8, 8.7]
# Mild temperatures: [12.5, 14.2, 10.0]
# Comfortable temperatures: [17.3, 15.0, 18.6]

# %%
temperatures = [5, 12.5, 17.3, 9.8, 20.1, 14.2, 15.0, 18.6, 8.7, 10.0, 14.7, 16.9, 19.1]

cold = []
mild = []
comfortable = []

for temp in temperatures:
    if temp < 10:
        cold.append(temp)
    elif 10 <= temp < 15:
        mild.append(temp)
    elif 15 <= temp < 20:
        comfortable.append(temp)

cold_count = len(cold)
mild_count = len(mild)
comfortable_count = len(comfortable)

print("Cold temperatures count:", cold_count)
print("Mild temperatures count:", mild_count)
print("Comfortable temperatures count:", comfortable_count)
# Out:
# Cold temperatures count: 3
# Mild temperatures count: 4
# Comfortable temperatures count: 5

# %%
temperatures = [5, 12.5, 17.3, 9.8, 20.1, 14.2, 15.0, 18.6, 8.7, 10.0]

temperatures_fahrenheit = []

for temp in temperatures:
    fahrenheit = (temp * 9 / 5) + 32
    temperatures_fahrenheit.append(fahrenheit)

print("Temperatures in Fahrenheit:", temperatures_fahrenheit)
# Out:
# Temperatures in Fahrenheit: [41.0, 54.5, 63.14, 49.64, 68.18, 57.56, 59.0, 65.48, 47.66, 50.0]

# %%
import matplotlib.pyplot as plt

temperatures = [5, 12.5, 17.3, 9.8, 20.1, 14.2, 15.0, 18.6, 8.7, 10.0]

night_temperatures = []
evening_temperatures = []
day_temperatures = []

for i in range(len(temperatures)):
    if i % 3 == 0:
        night_temperatures.append(temperatures[i])
    elif i % 3 == 1:
        evening_temperatures.append(temperatures[i])
    else:
        day_temperatures.append(temperatures[i])

average_day_temperature = sum(day_temperatures) / len(day_temperatures)

print("Night temperatures:", night_temperatures)
print("Evening temperatures:", evening_temperatures)
print("Day temperatures:", day_temperatures)
print(f"Average day-time temperature: {average_day_temperature:.2f}°C")

days = list(range(1, len(day_temperatures) + 1))
plt.figure(figsize=(10, 6))
plt.plot(days, day_temperatures, marker='o', color='blue', label='Day Temperatures')
plt.title("Day vs. Temperature")
plt.xlabel("Day")
plt.ylabel("Temperature (°C)")
plt.grid(True)
plt.legend()
plt.show()
# Out:
# Night temperatures: [5, 9.8, 15.0, 10.0]
# Evening temperatures: [12.5, 20.1, 18.6]
# Day temperatures: [17.3, 14.2, 8.7]
# Average day-time temperature: 13.40°C

# %%
def sum_nested_list(nested_list):
    total = 0
    for element in nested_list:
        if isinstance(element, list):
            total += sum_nested_list(element)
        else:
            total += element
    return total

nested_list = [1, [2, [3, 4], 5], 6, [7, 8]]
result = sum_nested_list(nested_list)
print("The total sum is:", result)
# Out:
# The total sum is: 36

# %%
def generate_permutations(s):
    def permute(prefix, remaining, results):
        if not remaining:
            results.add(prefix)
        else:
            for i in range(len(remaining)):
                permute(prefix + remaining[i], remaining[:i] + remaining[i+1:], results)

    results = set()
    permute("", s, results)
    return sorted(results)

print(generate_permutations("abc"))
print(generate_permutations("aab"))
# Out:
# ['abc', 'acb', 'bac', 'bca', 'cab', 'cba']
# ['aab', 'aba', 'baa']

# %%
def calculate_directory_size(directory):
    total_size = 0
    for item in directory:
        if isinstance(item, dict):
            for subdirectory, contents in item.items():
                total_size += calculate_directory_size(contents)
        else:
            total_size += item
    return total_size

directory = [
    150,
    {"subdir1": [300, 400]},
    {"subdir2": [75, {"subsubdir": [50, 100]}]},
]

total_size = calculate_directory_size(directory)
print(f"Total size of directory: {total_size} KB")
# Out:
# Total size of directory: 1075 KB

# %%
def min_coins(coins, amount):
    max_value = amount + 1
    dp = [max_value] * (amount + 1)
    dp[0] = 0
    for coin in coins:
        for x in range(coin, amount + 1):
            dp[x] = min(dp[x], dp[x - coin] + 1)
    return dp[amount] if dp[amount] <= amount else -1

coins = [1, 2, 5]
amount = 11
result = min_coins(coins, amount)
print(f"Minimum coins needed for amount {amount}: {result}")
# Out:
# Minimum coins needed for amount 11: 3

# %%
def longest_common_subsequence(s1, s2):
    m, n = len(s1), len(s2)
    dp = [[0] * (n + 1) for _ in range(m + 1)]

    for i in range(1, m + 1):
        for j in range(1, n + 1):
            if s1[i - 1] == s2[j - 1]:
                dp[i][j] = dp[i - 1][j - 1] + 1
            else:
                dp[i][j] = max(dp[i - 1][j], dp[i][j - 1])

    return dp[m][n]

s1 = "abcde"
s2 = "ace"
result = longest_common_subsequence(s1, s2)
print(f"Length of LCS between '{s1}' and '{s2}': {result}")
# Out:
# Length of LCS between 'abcde' and 'ace': 3

# %%
def knapsack(weights, values, capacity):
    n = len(weights)
    dp = [0] * (capacity + 1)

    for i in range(n):
        for w in range(capacity, weights[i] - 1, -1):
            dp[w] = max(dp[w], dp[w - weights[i]] + values[i])

    return dp[capacity]

weights = [1, 3, 4, 5]
values = [1, 4, 5, 7]
capacity = 7
result = knapsack(weights, values, capacity)
print(f"Maximum value in Knapsack with capacity {capacity}: {result}")
# Out:
# Maximum value in Knapsack with capacity 7: 9
